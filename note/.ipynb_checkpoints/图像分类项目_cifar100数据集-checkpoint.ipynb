# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
#cifar100数据集
(train_images, train_labels), (test_images, test_labels) = datasets.cifar100.load_data()
#归一化
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
dic = {}
for label in train_labels:
  x = int(label)
  if x not in dic:
    dic[x] = 1
  else:
    dic[x] += 1
print(dic)

print(train_images[0].shape)
print(train_images[100].shape)
print(train_images[10000].shape)
# Out:
# {19: 500, 29: 500, 0: 500, 11: 500, 1: 500, 86: 500, 90: 500, 28: 500, 23: 500, 31: 500, 39: 500, 96: 500, 82: 500, 17: 500, 71: 500, 8: 500, 97: 500, 80: 500, 74: 500, 59: 500, 70: 500, 87: 500, 84: 500, 64: 500, 52: 500, 42: 500, 47: 500, 65: 500, 21: 500, 22: 500, 81: 500, 24: 500, 78: 500, 45: 500, 49: 500, 56: 500, 76: 500, 89: 500, 73: 500, 14: 500, 9: 500, 6: 500, 20: 500, 98: 500, 36: 500, 55: 500, 72: 500, 43: 500, 51: 500, 35: 500, 83: 500, 33: 500, 27: 500, 53: 500, 92: 500, 50: 500, 15: 500, 18: 500, 46: 500, 75: 500, 38: 500, 66: 500, 77: 500, 69: 500, 95: 500, 99: 500, 93: 500, 4: 500, 61: 500, 94: 500, 68: 500, 34: 500, 32: 500, 88: 500, 67: 500, 30: 500, 62: 500, 63: 500, 40: 500, 26: 500, 48: 500, 79: 500, 85: 500, 54: 500, 44: 500, 7: 500, 12: 500, 2: 500, 41: 500, 37: 500, 13: 500, 25: 500, 10: 500, 57: 500, 5: 500, 60: 500, 91: 500, 3: 500, 58: 500, 16: 500}
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels[i][0])
plt.show()

# %%
#搭建模型
model = models.Sequential()
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Flatten()) #Flatten层用来将输入“压平”，即把多维的输入一维化，常用在从卷积层到全连接层的过渡。Flatten不影响batch的大小。
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(100, activation='softmax'))

# %%
#在小规模训练集上训练
train_images1 = train_images[0:100]
train_labels1 = train_labels[0:100]
test_images1 = test_images[0:100]
test_labels1 = test_labels[0:100]

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history1 = model.fit(train_images1, train_labels1, epochs=100,
                    validation_data=(test_images1, test_labels1))


plt.plot(history1.history['loss'], label='loss')
plt.plot(history1.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 63ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5091 - val_accuracy: 0.3000
# Epoch 2/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5130 - val_accuracy: 0.3000
# Epoch 3/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5175 - val_accuracy: 0.3000
# Epoch 4/100
# 4/4 [==============================] - 0s 34ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5190 - val_accuracy: 0.3000
# Epoch 5/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5187 - val_accuracy: 0.3000
# Epoch 6/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5161 - val_accuracy: 0.3000
# Epoch 7/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5161 - val_accuracy: 0.3000
# Epoch 8/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5174 - val_accuracy: 0.3000
# Epoch 9/100
# 4/4 [==============================] - 0s 34ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5230 - val_accuracy: 0.3000
# Epoch 10/100
# 4/4 [==============================] - 0s 36ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5233 - val_accuracy: 0.3000
# Epoch 11/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5247 - val_accuracy: 0.3000
# Epoch 12/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5292 - val_accuracy: 0.3000
# Epoch 13/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5339 - val_accuracy: 0.3100
# Epoch 14/100
# 4/4 [==============================] - 0s 35ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5330 - val_accuracy: 0.3100
# Epoch 15/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5334 - val_accuracy: 0.3100
# Epoch 16/100
# 4/4 [==============================] - 0s 36ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5274 - val_accuracy: 0.3100
# Epoch 17/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5127 - val_accuracy: 0.2900
# Epoch 18/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5056 - val_accuracy: 0.3000
# Epoch 19/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5024 - val_accuracy: 0.3000
# Epoch 20/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5013 - val_accuracy: 0.3000
# Epoch 21/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5002 - val_accuracy: 0.3000
# Epoch 22/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5005 - val_accuracy: 0.3000
# Epoch 23/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4977 - val_accuracy: 0.3000
# Epoch 24/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4961 - val_accuracy: 0.3000
# Epoch 25/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4940 - val_accuracy: 0.3000
# Epoch 26/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4911 - val_accuracy: 0.3000
# Epoch 27/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4911 - val_accuracy: 0.3000
# Epoch 28/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4939 - val_accuracy: 0.3000
# Epoch 29/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4987 - val_accuracy: 0.3100
# Epoch 30/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5084 - val_accuracy: 0.3100
# Epoch 31/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5257 - val_accuracy: 0.3100
# Epoch 32/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5409 - val_accuracy: 0.3100
# Epoch 33/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5588 - val_accuracy: 0.3100
# Epoch 34/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5788 - val_accuracy: 0.3200
# Epoch 35/100
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5830 - val_accuracy: 0.3200
# Epoch 36/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5838 - val_accuracy: 0.3200
# Epoch 37/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5868 - val_accuracy: 0.3200
# Epoch 38/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.5885 - val_accuracy: 0.3100
# Epoch 39/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6001 - val_accuracy: 0.3000
# Epoch 40/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6132 - val_accuracy: 0.3100
# Epoch 41/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.6279 - val_accuracy: 0.3100
# Epoch 42/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.6271 - val_accuracy: 0.3200
# Epoch 43/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6315 - val_accuracy: 0.3200
# Epoch 44/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6385 - val_accuracy: 0.3200
# Epoch 45/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.6322 - val_accuracy: 0.3200
# Epoch 46/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6054 - val_accuracy: 0.3100
# Epoch 47/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5955 - val_accuracy: 0.3100
# Epoch 48/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5973 - val_accuracy: 0.3100
# Epoch 49/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6006 - val_accuracy: 0.3200
# Epoch 50/100
# 4/4 [==============================] - 0s 36ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.6073 - val_accuracy: 0.3200
# Epoch 51/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6175 - val_accuracy: 0.3200
# Epoch 52/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6320 - val_accuracy: 0.3300
# Epoch 53/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6495 - val_accuracy: 0.3300
# Epoch 54/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6697 - val_accuracy: 0.3300
# Epoch 55/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6843 - val_accuracy: 0.3300
# Epoch 56/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6931 - val_accuracy: 0.3300
# Epoch 57/100
# 4/4 [==============================] - 0s 35ms/step - loss: 2.3842e-09 - accuracy: 1.0000 - val_loss: 9.7020 - val_accuracy: 0.3400
# Epoch 58/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7147 - val_accuracy: 0.3200
# Epoch 59/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7307 - val_accuracy: 0.3300
# Epoch 60/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7503 - val_accuracy: 0.3400
# Epoch 61/100
# 4/4 [==============================] - 0s 38ms/step - loss: 2.3842e-09 - accuracy: 1.0000 - val_loss: 9.7617 - val_accuracy: 0.3400
# Epoch 62/100
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.7739 - val_accuracy: 0.3300
# Epoch 63/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7928 - val_accuracy: 0.3200
# Epoch 64/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8108 - val_accuracy: 0.3400
# Epoch 65/100
# 4/4 [==============================] - 0s 37ms/step - loss: 3.5763e-09 - accuracy: 1.0000 - val_loss: 9.8203 - val_accuracy: 0.3200
# Epoch 66/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8295 - val_accuracy: 0.3100
# Epoch 67/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8403 - val_accuracy: 0.3000
# Epoch 68/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8503 - val_accuracy: 0.3300
# Epoch 69/100
# 4/4 [==============================] - 0s 37ms/step - loss: 3.5763e-09 - accuracy: 1.0000 - val_loss: 9.8514 - val_accuracy: 0.3400
# Epoch 70/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8560 - val_accuracy: 0.3300
# Epoch 71/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8640 - val_accuracy: 0.3300
# Epoch 72/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8719 - val_accuracy: 0.3300
# Epoch 73/100
# 4/4 [==============================] - 0s 47ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.8743 - val_accuracy: 0.3300
# Epoch 74/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8752 - val_accuracy: 0.3400
# Epoch 75/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8955 - val_accuracy: 0.3400
# Epoch 76/100
# 4/4 [==============================] - 0s 38ms/step - loss: 5.9605e-09 - accuracy: 1.0000 - val_loss: 9.9137 - val_accuracy: 0.3200
# Epoch 77/100
# 4/4 [==============================] - 0s 38ms/step - loss: 2.3842e-09 - accuracy: 1.0000 - val_loss: 9.8432 - val_accuracy: 0.3000
# Epoch 78/100
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.7211 - val_accuracy: 0.3300
# Epoch 79/100
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.6838 - val_accuracy: 0.3200
# Epoch 80/100
# 4/4 [==============================] - 0s 39ms/step - loss: 2.3842e-09 - accuracy: 1.0000 - val_loss: 9.6704 - val_accuracy: 0.3100
# Epoch 81/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6796 - val_accuracy: 0.3200
# Epoch 82/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.6884 - val_accuracy: 0.3200
# Epoch 83/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7040 - val_accuracy: 0.3100
# Epoch 84/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7164 - val_accuracy: 0.3100
# Epoch 85/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7339 - val_accuracy: 0.3100
# Epoch 86/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7522 - val_accuracy: 0.3000
# Epoch 87/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7673 - val_accuracy: 0.2900
# Epoch 88/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7840 - val_accuracy: 0.3100
# Epoch 89/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7994 - val_accuracy: 0.3100
# Epoch 90/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8149 - val_accuracy: 0.3100
# Epoch 91/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8326 - val_accuracy: 0.2900
# Epoch 92/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8524 - val_accuracy: 0.2900
# Epoch 93/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1921e-09 - accuracy: 1.0000 - val_loss: 9.8594 - val_accuracy: 0.3000
# Epoch 94/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8674 - val_accuracy: 0.3100
# Epoch 95/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8763 - val_accuracy: 0.3100
# Epoch 96/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8892 - val_accuracy: 0.3100
# Epoch 97/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.9035 - val_accuracy: 0.3100
# Epoch 98/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.9156 - val_accuracy: 0.3200
# Epoch 99/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.9270 - val_accuracy: 0.3200
# Epoch 100/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.9375 - val_accuracy: 0.3200

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 3.6729 - accuracy: 0.1532 - val_loss: 3.1692 - val_accuracy: 0.2351
# Epoch 2/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 2.8561 - accuracy: 0.2906 - val_loss: 2.7372 - val_accuracy: 0.3183
# Epoch 3/20
# 1563/1563 [==============================] - 65s 41ms/step - loss: 2.4410 - accuracy: 0.3723 - val_loss: 2.5579 - val_accuracy: 0.3537
# Epoch 4/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 2.1015 - accuracy: 0.4437 - val_loss: 2.5599 - val_accuracy: 0.3702
# Epoch 5/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 1.7987 - accuracy: 0.5123 - val_loss: 2.5348 - val_accuracy: 0.3812
# Epoch 6/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.4910 - accuracy: 0.5835 - val_loss: 2.6705 - val_accuracy: 0.3742
# Epoch 7/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 1.1965 - accuracy: 0.6576 - val_loss: 3.0755 - val_accuracy: 0.3776
# Epoch 8/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.9322 - accuracy: 0.7261 - val_loss: 3.3860 - val_accuracy: 0.3636
# Epoch 9/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.7227 - accuracy: 0.7812 - val_loss: 3.8025 - val_accuracy: 0.3459
# Epoch 10/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5765 - accuracy: 0.8210 - val_loss: 4.2656 - val_accuracy: 0.3518
# Epoch 11/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4722 - accuracy: 0.8519 - val_loss: 4.7521 - val_accuracy: 0.3528
# Epoch 12/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.4091 - accuracy: 0.8693 - val_loss: 5.1836 - val_accuracy: 0.3426
# Epoch 13/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.3581 - accuracy: 0.8871 - val_loss: 5.5545 - val_accuracy: 0.3450
# Epoch 14/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.3253 - accuracy: 0.8968 - val_loss: 5.8161 - val_accuracy: 0.3430
# Epoch 15/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.3190 - accuracy: 0.9010 - val_loss: 5.9699 - val_accuracy: 0.3434
# Epoch 16/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.2973 - accuracy: 0.9075 - val_loss: 6.4912 - val_accuracy: 0.3420
# Epoch 17/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.2813 - accuracy: 0.9122 - val_loss: 6.6950 - val_accuracy: 0.3344
# Epoch 18/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.2558 - accuracy: 0.9207 - val_loss: 6.8541 - val_accuracy: 0.3387
# Epoch 19/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.2722 - accuracy: 0.9192 - val_loss: 6.7738 - val_accuracy: 0.3349
# Epoch 20/20
# 1563/1563 [==============================] - 65s 41ms/step - loss: 0.2337 - accuracy: 0.9284 - val_loss: 7.5941 - val_accuracy: 0.3355

# %%
#减小模型
model1 = models.Sequential()
model1.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Conv2D(32, (3, 3), activation='relu'))
model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Conv2D(32, (3, 3), activation='relu'))
model1.add(layers.Flatten())
model1.add(layers.Dense(100, activation='softmax'))

model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history2 = model1.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
plt.plot(history2.history['loss'], label='loss')
plt.plot(history2.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 24s 15ms/step - loss: 3.7924 - accuracy: 0.1255 - val_loss: 3.3590 - val_accuracy: 0.2035
# Epoch 2/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 3.1533 - accuracy: 0.2427 - val_loss: 3.0215 - val_accuracy: 0.2616
# Epoch 3/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.9029 - accuracy: 0.2896 - val_loss: 2.9163 - val_accuracy: 0.2937
# Epoch 4/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.7523 - accuracy: 0.3184 - val_loss: 2.8500 - val_accuracy: 0.3023
# Epoch 5/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.6395 - accuracy: 0.3400 - val_loss: 2.7695 - val_accuracy: 0.3173
# Epoch 6/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.5421 - accuracy: 0.3623 - val_loss: 2.7271 - val_accuracy: 0.3266
# Epoch 7/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.4656 - accuracy: 0.3770 - val_loss: 2.6835 - val_accuracy: 0.3372
# Epoch 8/20
# 1563/1563 [==============================] - 23s 15ms/step - loss: 2.3998 - accuracy: 0.3904 - val_loss: 2.6657 - val_accuracy: 0.3383
# Epoch 9/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.3417 - accuracy: 0.4039 - val_loss: 2.6577 - val_accuracy: 0.3434
# Epoch 10/20
# 1563/1563 [==============================] - 23s 14ms/step - loss: 2.2957 - accuracy: 0.4130 - val_loss: 2.6990 - val_accuracy: 0.3350
# Epoch 11/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.2474 - accuracy: 0.4229 - val_loss: 2.6704 - val_accuracy: 0.3542
# Epoch 12/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.2110 - accuracy: 0.4307 - val_loss: 2.6124 - val_accuracy: 0.3581
# Epoch 13/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.1719 - accuracy: 0.4383 - val_loss: 2.6654 - val_accuracy: 0.3489
# Epoch 14/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.1372 - accuracy: 0.4461 - val_loss: 2.6115 - val_accuracy: 0.3582
# Epoch 15/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.1085 - accuracy: 0.4521 - val_loss: 2.7223 - val_accuracy: 0.3399
# Epoch 16/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.0678 - accuracy: 0.4616 - val_loss: 2.6641 - val_accuracy: 0.3563
# Epoch 17/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.0398 - accuracy: 0.4658 - val_loss: 2.6303 - val_accuracy: 0.3595
# Epoch 18/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.0123 - accuracy: 0.4747 - val_loss: 2.6574 - val_accuracy: 0.3541
# Epoch 19/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 1.9842 - accuracy: 0.4792 - val_loss: 2.6773 - val_accuracy: 0.3536
# Epoch 20/20
# 1563/1563 [==============================] - 22s 14ms/step - loss: 1.9657 - accuracy: 0.4834 - val_loss: 2.7453 - val_accuracy: 0.3507

# %%
#正则化
model2 = models.Sequential()
model2.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model2.add(layers.Flatten())
model2.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model2.add(layers.Dense(100, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))

model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history8 = model2.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
plt.plot(history8.history['loss'], label='loss')
plt.plot(history8.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 4.0926 - accuracy: 0.0833 - val_loss: 3.6647 - val_accuracy: 0.1605
# Epoch 2/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 3.4852 - accuracy: 0.1912 - val_loss: 3.3406 - val_accuracy: 0.2288
# Epoch 3/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 3.2269 - accuracy: 0.2471 - val_loss: 3.2325 - val_accuracy: 0.2618
# Epoch 4/20
#  291/1563 [====>.........................] - ETA: 49s - loss: 3.0607 - accuracy: 0.2870
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-573f9c1ac856> in <module>
#      15
#      16 history8 = model2.fit(train_images, train_labels, epochs=20,
# ---> 17                     validation_data=(test_images, test_labels))
#      18
#      19 plt.plot(history8.history['loss'], label='loss')
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/.virtualenvs/jupyter-notebook-IDE/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
#正则化
model3 = models.Sequential()
model3.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=tf.keras.regularizers.l2(l=0.005)))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.005)))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.005)))
model3.add(layers.Flatten())
model3.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.005)))
model3.add(layers.Dense(100, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(l=0.005)))

model3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history3 = model3.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
plt.plot(history3.history['loss'], label='loss')
plt.plot(history3.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
#正则化+减小参数
model4 = models.Sequential()
model4.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.MaxPooling2D((2, 2)))
model4.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.MaxPooling2D((2, 2)))
model4.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.Flatten())
model4.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.Dense(100, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))

model4.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history4 = model4.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
plt.plot(history4.history['loss'], label='loss')
plt.plot(history4.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
#搭建模型，droupout 就是不激活所有的神经元，激活部分，好比识别一只猫需要5个神经元（五官），但是，有些是残疾的没有完整的五官，这时候关闭一些神经元会增大模型表现
model5 = models.Sequential()
model5.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model5.add(layers.MaxPooling2D((2, 2)))
model5.add(layers.Dropout(0.2))
model5.add(layers.Conv2D(128, (3, 3), activation='relu'))
model5.add(layers.MaxPooling2D((2, 2)))
model5.add(layers.Dropout(0.2))
model5.add(layers.Conv2D(128, (3, 3), activation='relu'))
model5.add(layers.Flatten())
model5.add(layers.Dense(512, activation='relu'))
model5.add(layers.Dense(100, activation='softmax'))

model5.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history5 = model5.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
plt.plot(history5.history['loss'], label='loss')
plt.plot(history5.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
#搭建模型，droupout
model6 = models.Sequential()
model6.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model6.add(layers.MaxPooling2D((2, 2)))
model6.add(layers.Dropout(0.1))
model6.add(layers.Conv2D(128, (3, 3), activation='relu'))
model6.add(layers.MaxPooling2D((2, 2)))
model6.add(layers.Dropout(0.1))
model6.add(layers.Conv2D(128, (3, 3), activation='relu'))
model6.add(layers.Flatten())
model6.add(layers.Dense(512, activation='relu'))
model6.add(layers.Dense(100, activation='softmax'))

model6.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history6 = model6.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
plt.plot(history6.history['loss'], label='loss')
plt.plot(history6.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
#搭建模型，droupout
model7 = models.Sequential()
model7.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model7.add(layers.MaxPooling2D((2, 2)))
model7.add(layers.Conv2D(128, (3, 3), activation='relu'))
model7.add(layers.MaxPooling2D((2, 2)))
model7.add(layers.Conv2D(128, (3, 3), activation='relu'))
model7.add(layers.Flatten())
model7.add(layers.Dense(512, activation='relu'))
model7.add(layers.Dropout(0.2))
model7.add(layers.Dense(100, activation='softmax'))

model7.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history7 = model7.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
                    plt.plot(history7.history['loss'], label='loss')
plt.plot(history7.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
#正则化+减小参数
model4 = models.Sequential()
model4.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.MaxPooling2D((2, 2)))
model4.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.MaxPooling2D((2, 2)))
model4.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.Flatten())
model4.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))
model4.add(layers.Dense(100, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(l=0.0005)))

model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(train_images, train_labels, epochs=20, initial_epoch=0
                    validation_data=(test_images, test_labels))
                    
model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(train_images, train_labels, epochs=40,
                    validation_data=(test_images, test_labels))
                    
model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.002),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
                    
model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(train_images, train_labels, epochs=20, initial_epoch=0,
                    validation_data=(test_images, test_labels))
                    
model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(train_images, train_labels, epochs=40,
                    validation_data=(test_images, test_labels))
                   
model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(train_images, train_labels, epochs=15,
                    validation_data=(test_images, test_labels))

model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history1 = model4.fit(train_images, train_labels, epochs=5,
                    validation_data=(test_images, test_labels))
                    
plt.plot(history.history['loss']+history1.history['loss'],label='loss')
plt.plot(history.history['val_loss']+history1.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
